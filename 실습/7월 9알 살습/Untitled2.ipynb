# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
import requests

cookies = {
    '_fbp': 'fb.1.1656726532642.2004251766',
    'PHPSESSID': 'nd59d1stncdcuklmfg0rhlj83gkq6cf5roe7lmue9c0dc96gptq0',
    'cookie_check': '0',
    'shop_authenticate': 'Y',
    '__cfruid': '820f38267a29dbd7ad9ab0389ac72e116ed91953-1657350349',
    '_gid': 'GA1.2.509111178.1657350354',
    '_gac_UA-90734988-1': '1.1657350354.Cj0KCQjwzqSWBhDPARIsAK38LY-xaqK9eEDdQmI7I-ovfLYNPO67eOgvPdfI5yrsD4WomG4aTnBEkaMaAnbDEALw_wcB',
    'gd_user_enamooPass': 'Xndsc0ZQbGJHTV94R2dKckRmQnJHPDB3SVFTX0VQVipIc0kwSEFWckU%2FRjA%3D',
    'Xtime': '1657350610',
    '_ga_2K2GN0FFY0': 'GS1.1.1657350354.4.1.1657350612.59',
    '_ga': 'GA1.2.717390620.1656724274',
    'amplitude_id_65bebb55595beb82e78d5d1ae808702ckurly.com': 'eyJkZXZpY2VJZCI6Ijk0OGQyNWI5LTFjYTUtNGNiMS05MmMwLTk5MGI5MGVhZTQ1ZlIiLCJ1c2VySWQiOm51bGwsIm9wdE91dCI6ZmFsc2UsInNlc3Npb25JZCI6MTY1NzM1MDM1NDI4NiwibGFzdEV2ZW50VGltZSI6MTY1NzM1MDYxMjMxNSwiZXZlbnRJZCI6MTM1LCJpZGVudGlmeUlkIjozLCJzZXF1ZW5jZU51bWJlciI6MTM4fQ==',
}

headers = {
    'authority': 'www.kurly.com',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    'cache-control': 'max-age=0',
    # Requests sorts cookies= alphabetically
    # 'cookie': '_fbp=fb.1.1656726532642.2004251766; PHPSESSID=nd59d1stncdcuklmfg0rhlj83gkq6cf5roe7lmue9c0dc96gptq0; cookie_check=0; shop_authenticate=Y; __cfruid=820f38267a29dbd7ad9ab0389ac72e116ed91953-1657350349; _gid=GA1.2.509111178.1657350354; _gac_UA-90734988-1=1.1657350354.Cj0KCQjwzqSWBhDPARIsAK38LY-xaqK9eEDdQmI7I-ovfLYNPO67eOgvPdfI5yrsD4WomG4aTnBEkaMaAnbDEALw_wcB; gd_user_enamooPass=Xndsc0ZQbGJHTV94R2dKckRmQnJHPDB3SVFTX0VQVipIc0kwSEFWckU%2FRjA%3D; Xtime=1657350610; _ga_2K2GN0FFY0=GS1.1.1657350354.4.1.1657350612.59; _ga=GA1.2.717390620.1656724274; amplitude_id_65bebb55595beb82e78d5d1ae808702ckurly.com=eyJkZXZpY2VJZCI6Ijk0OGQyNWI5LTFjYTUtNGNiMS05MmMwLTk5MGI5MGVhZTQ1ZlIiLCJ1c2VySWQiOm51bGwsIm9wdE91dCI6ZmFsc2UsInNlc3Npb25JZCI6MTY1NzM1MDM1NDI4NiwibGFzdEV2ZW50VGltZSI6MTY1NzM1MDYxMjMxNSwiZXZlbnRJZCI6MTM1LCJpZGVudGlmeUlkIjozLCJzZXF1ZW5jZU51bWJlciI6MTM4fQ==',
    'referer': 'https://www.kurly.com/shop/goods/goods_list.php?category=038',
    'sec-ch-ua': '".Not/A)Brand";v="99", "Google Chrome";v="103", "Chromium";v="103"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36',
}

params = {
    'category': '038',
}

response = requests.get('https://www.kurly.com/shop/goods/goods_list.php', params=params, cookies=cookies, headers=headers)
